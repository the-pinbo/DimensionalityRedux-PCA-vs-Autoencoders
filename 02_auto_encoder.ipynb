# %% [markdown]
# <a href="https://colab.research.google.com/github/the-pinbo/image-compression/blob/main/04_auto_encoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import peak_signal_noise_ratio as compare_psnr
from skimage.metrics import structural_similarity as compare_ssim

# %%
# Download the dataset
mnist = tf.keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype('float32') / 255.
print(f"X_train.shape => {X_train.shape}")
print(f"X_test.shape => {X_test.shape}")
print(f"Y_train.shape => {Y_train.shape}")
print(f"Y_test.shape => {Y_test.shape}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# X_train.shape => (60000, 28, 28)
# X_test.shape => (10000, 28, 28)
# Y_train.shape => (60000,)
# Y_test.shape => (10000,)

# %%
def build_autoencoder(input_shape, latent_dim, encoder_units, decoder_units, dropout_rate):
    # Encoder
    encoder_input = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Flatten()(encoder_input)
    for units in encoder_units:
        x = tf.keras.layers.Dense(units, activation='relu')(x)
        x = tf.keras.layers.Dropout(dropout_rate)(x)
    encoded_output = tf.keras.layers.Dense(latent_dim, activation='relu')(x)
    encoder = tf.keras.Model(inputs=encoder_input, outputs=encoded_output, name='encoder')

    # Decoder
    decoder_input = tf.keras.Input(shape=(latent_dim,))
    x = decoder_input
    for units in decoder_units:
        x = tf.keras.layers.Dense(units, activation='relu')(x)
        x = tf.keras.layers.Dropout(dropout_rate)(x)
    x = tf.keras.layers.Dense(tf.math.reduce_prod(input_shape), activation='relu')(x)
    decoded_output = tf.keras.layers.Reshape(input_shape)(x)
    decoder = tf.keras.Model(inputs=decoder_input, outputs=decoded_output, name='decoder')

    # Autoencoder
    autoencoder_input = tf.keras.Input(shape=input_shape)
    encoded = encoder(autoencoder_input)
    decoded = decoder(encoded)
    autoencoder = tf.keras.Model(inputs=autoencoder_input, outputs=decoded, name='autoencoder')

    return autoencoder, encoder, decoder

# %%
def calculate_psnr(original, reconstructed):
    return compare_psnr(original, reconstructed, data_range=original.max() - original.min())

def calculate_ssim(original, reconstructed):
    return compare_ssim(original, reconstructed, multichannel=True)

# %%
def predict_model(model, X_test):
    predictions = model.predict(X_test)
    return predictions


def plot_training_history(history):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss During Training')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Define model parameters
input_shape = X_train.shape[1:]
dropout_rate = 0.2
output_shape = X_train.shape[1:]
encoder_units = [512, 256, 128]
decoder_units = [128, 256, 512]

# %%
latent_dims = [2, 8, 32, 64]
autoencoders = dict()
encoders = dict()
decoders = dict()

for latent_dim in latent_dims:
    # Build and compile the autoencoder
    autoencoder, encoder, decoder = build_autoencoder(input_shape, latent_dim, encoder_units, decoder_units, dropout_rate)
    autoencoder.compile(loss='mae', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))
    autoencoders[latent_dim] = autoencoder
    encoders[latent_dim] = encoder
    decoders[latent_dim] = decoder
    print(f"Latent dim => {latent_dim}")
    print(autoencoder.summary(expand_nested=True))
# Out:
# Latent dim => 2
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28)]          0
#
#  encoder (Functional)        (None, 2)                 566402
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_1 (InputLayer)       [(None, 28, 28)]          0        |
# |                                                               |
# | flatten (Flatten)          (None, 784)               0        |
# |                                                               |
# | dense (Dense)              (None, 512)               401920   |
# |                                                               |
# | dropout (Dropout)          (None, 512)               0        |
# |                                                               |
# | dense_1 (Dense)            (None, 256)               131328   |
# |                                                               |
# | dropout_1 (Dropout)        (None, 256)               0        |
# |                                                               |
# | dense_2 (Dense)            (None, 128)               32896    |
# |                                                               |
# | dropout_2 (Dropout)        (None, 128)               0        |
# |                                                               |
# | dense_3 (Dense)            (None, 2)                 258      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  decoder (Functional)        (None, 28, 28)            567184
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_2 (InputLayer)       [(None, 2)]               0        |
# |                                                               |
# | dense_4 (Dense)            (None, 128)               384      |
# |                                                               |
# | dropout_3 (Dropout)        (None, 128)               0        |
# |                                                               |
# | dense_5 (Dense)            (None, 256)               33024    |
# |                                                               |
# | dropout_4 (Dropout)        (None, 256)               0        |
# |                                                               |
# | dense_6 (Dense)            (None, 512)               131584   |
# |                                                               |
# | dropout_5 (Dropout)        (None, 512)               0        |
# |                                                               |
# | dense_7 (Dense)            (None, 784)               402192   |
# |                                                               |
# | reshape (Reshape)          (None, 28, 28)            0        |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 1133586 (4.32 MB)
# Trainable params: 1133586 (4.32 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Latent dim => 8
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 28, 28)]          0
#
#  encoder (Functional)        (None, 8)                 567176
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_4 (InputLayer)       [(None, 28, 28)]          0        |
# |                                                               |
# | flatten_1 (Flatten)        (None, 784)               0        |
# |                                                               |
# | dense_8 (Dense)            (None, 512)               401920   |
# |                                                               |
# | dropout_6 (Dropout)        (None, 512)               0        |
# |                                                               |
# | dense_9 (Dense)            (None, 256)               131328   |
# |                                                               |
# | dropout_7 (Dropout)        (None, 256)               0        |
# |                                                               |
# | dense_10 (Dense)           (None, 128)               32896    |
# |                                                               |
# | dropout_8 (Dropout)        (None, 128)               0        |
# |                                                               |
# | dense_11 (Dense)           (None, 8)                 1032     |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  decoder (Functional)        (None, 28, 28)            567952
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_5 (InputLayer)       [(None, 8)]               0        |
# |                                                               |
# | dense_12 (Dense)           (None, 128)               1152     |
# |                                                               |
# | dropout_9 (Dropout)        (None, 128)               0        |
# |                                                               |
# | dense_13 (Dense)           (None, 256)               33024    |
# |                                                               |
# | dropout_10 (Dropout)       (None, 256)               0        |
# |                                                               |
# | dense_14 (Dense)           (None, 512)               131584   |
# |                                                               |
# | dropout_11 (Dropout)       (None, 512)               0        |
# |                                                               |
# | dense_15 (Dense)           (None, 784)               402192   |
# |                                                               |
# | reshape_1 (Reshape)        (None, 28, 28)            0        |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 1135128 (4.33 MB)
# Trainable params: 1135128 (4.33 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Latent dim => 32
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 28, 28)]          0
#
#  encoder (Functional)        (None, 32)                570272
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_7 (InputLayer)       [(None, 28, 28)]          0        |
# |                                                               |
# | flatten_2 (Flatten)        (None, 784)               0        |
# |                                                               |
# | dense_16 (Dense)           (None, 512)               401920   |
# |                                                               |
# | dropout_12 (Dropout)       (None, 512)               0        |
# |                                                               |
# | dense_17 (Dense)           (None, 256)               131328   |
# |                                                               |
# | dropout_13 (Dropout)       (None, 256)               0        |
# |                                                               |
# | dense_18 (Dense)           (None, 128)               32896    |
# |                                                               |
# | dropout_14 (Dropout)       (None, 128)               0        |
# |                                                               |
# | dense_19 (Dense)           (None, 32)                4128     |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  decoder (Functional)        (None, 28, 28)            571024
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_8 (InputLayer)       [(None, 32)]              0        |
# |                                                               |
# | dense_20 (Dense)           (None, 128)               4224     |
# |                                                               |
# | dropout_15 (Dropout)       (None, 128)               0        |
# |                                                               |
# | dense_21 (Dense)           (None, 256)               33024    |
# |                                                               |
# | dropout_16 (Dropout)       (None, 256)               0        |
# |                                                               |
# | dense_22 (Dense)           (None, 512)               131584   |
# |                                                               |
# | dropout_17 (Dropout)       (None, 512)               0        |
# |                                                               |
# | dense_23 (Dense)           (None, 784)               402192   |
# |                                                               |
# | reshape_2 (Reshape)        (None, 28, 28)            0        |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 1141296 (4.35 MB)
# Trainable params: 1141296 (4.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Latent dim => 64
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 28, 28)]          0
#
#  encoder (Functional)        (None, 64)                574400
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_10 (InputLayer)      [(None, 28, 28)]          0        |
# |                                                               |
# | flatten_3 (Flatten)        (None, 784)               0        |
# |                                                               |
# | dense_24 (Dense)           (None, 512)               401920   |
# |                                                               |
# | dropout_18 (Dropout)       (None, 512)               0        |
# |                                                               |
# | dense_25 (Dense)           (None, 256)               131328   |
# |                                                               |
# | dropout_19 (Dropout)       (None, 256)               0        |
# |                                                               |
# | dense_26 (Dense)           (None, 128)               32896    |
# |                                                               |
# | dropout_20 (Dropout)       (None, 128)               0        |
# |                                                               |
# | dense_27 (Dense)           (None, 64)                8256     |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  decoder (Functional)        (None, 28, 28)            575120
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_11 (InputLayer)      [(None, 64)]              0        |
# |                                                               |
# | dense_28 (Dense)           (None, 128)               8320     |
# |                                                               |
# | dropout_21 (Dropout)       (None, 128)               0        |
# |                                                               |
# | dense_29 (Dense)           (None, 256)               33024    |
# |                                                               |
# | dropout_22 (Dropout)       (None, 256)               0        |
# |                                                               |
# | dense_30 (Dense)           (None, 512)               131584   |
# |                                                               |
# | dropout_23 (Dropout)       (None, 512)               0        |
# |                                                               |
# | dense_31 (Dense)           (None, 784)               402192   |
# |                                                               |
# | reshape_3 (Reshape)        (None, 28, 28)            0        |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 1149520 (4.39 MB)
# Trainable params: 1149520 (4.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
def visualize_reconstructions(original, reconstructed, n_images, title):
    plt.figure(figsize=(20, 4))
    for i in range(n_images):
        # Display original image
        ax = plt.subplot(2, n_images, i + 1)
        plt.imshow(original[i].reshape(28, 28), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Display reconstructed image
        ax = plt.subplot(2, n_images, i + 1 + n_images)
        plt.imshow(reconstructed[i].reshape(28, 28), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    plt.suptitle(title)
    plt.show()

def train_model(model, X_train, epochs, batch_size, patience=5):
    """
    Trains the given model on the provided data with early stopping.

    Parameters:
    model: A TensorFlow/Keras model.
    X_train (np.array): Training data.
    epochs (int): Number of epochs to train the model.
    batch_size (int): Batch size for training.
    patience (int): Number of epochs to wait for improvement before stopping.

    Returns:
    history: Training history object.
    """
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=patience, restore_best_weights=True)

    history = model.fit(X_train, X_train, epochs=epochs, batch_size=batch_size,
                        validation_split=0.2, callbacks=[early_stopping])
    return history

# %%
reconstructed_images = dict()
psnr_values = []
ssim_values = []
n_images_to_display = 10

for latent_dim, autoencoder in autoencoders.items():
    print(f"Latent dim => {latent_dim}")
    # Train the model
    history = train_model(autoencoder, X_train, epochs=50, batch_size=512)
    # Predict using the model
    predictions = predict_model(autoencoder, X_test)
    reconstructed_images[latent_dim] = predictions
    # Plot the training history
    plot_training_history(history)

    # Calculate PSNR and SSIM
    psnr = calculate_psnr(X_test, predictions)
    ssim = calculate_ssim(X_test, predictions)
    psnr_values.append(psnr)
    ssim_values.append(ssim)

    # Visualization
    title = f"Autoencoder with Latent Dimension {latent_dim} - PSNR: {psnr:.2f}, SSIM: {ssim:.2f}"
    visualize_reconstructions(X_test, predictions, n_images_to_display, title)
# Out:
# Latent dim => 2
# Epoch 1/50
# 94/94 [==============================] - 10s 16ms/step - loss: 0.1265 - val_loss: 0.1241
# Epoch 2/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.1249 - val_loss: 0.1241
# Epoch 3/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.1249 - val_loss: 0.1241
# Epoch 4/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.1249 - val_loss: 0.1241
# Epoch 5/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.1249 - val_loss: 0.1241
# Epoch 6/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.1249 - val_loss: 0.1241
# 313/313 [==============================] - 1s 2ms/step
# <ipython-input-4-2edf5d512d37>:5: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   return compare_ssim(original, reconstructed, multichannel=True)
# Latent dim => 8
# Epoch 1/50
# 94/94 [==============================] - 3s 10ms/step - loss: 0.1234 - val_loss: 0.1179
# Epoch 2/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.1155 - val_loss: 0.1099
# Epoch 3/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.1061 - val_loss: 0.1019
# Epoch 4/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.1016 - val_loss: 0.0987
# Epoch 5/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0980 - val_loss: 0.0929
# Epoch 6/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0914 - val_loss: 0.0849
# Epoch 7/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0859 - val_loss: 0.0791
# Epoch 8/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0817 - val_loss: 0.0752
# Epoch 9/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0783 - val_loss: 0.0710
# Epoch 10/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0759 - val_loss: 0.0687
# Epoch 11/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0741 - val_loss: 0.0669
# Epoch 12/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0727 - val_loss: 0.0656
# Epoch 13/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0716 - val_loss: 0.0646
# Epoch 14/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0707 - val_loss: 0.0635
# Epoch 15/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0700 - val_loss: 0.0633
# Epoch 16/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0693 - val_loss: 0.0622
# Epoch 17/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0688 - val_loss: 0.0617
# Epoch 18/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0683 - val_loss: 0.0612
# Epoch 19/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0678 - val_loss: 0.0608
# Epoch 20/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0673 - val_loss: 0.0604
# Epoch 21/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0670 - val_loss: 0.0599
# Epoch 22/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0666 - val_loss: 0.0595
# Epoch 23/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0663 - val_loss: 0.0594
# Epoch 24/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0660 - val_loss: 0.0588
# Epoch 25/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0656 - val_loss: 0.0588
# Epoch 26/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0652 - val_loss: 0.0583
# Epoch 27/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0650 - val_loss: 0.0580
# Epoch 28/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0647 - val_loss: 0.0577
# Epoch 29/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0645 - val_loss: 0.0573
# Epoch 30/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0642 - val_loss: 0.0574
# Epoch 31/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0640 - val_loss: 0.0569
# Epoch 32/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0637 - val_loss: 0.0565
# Epoch 33/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0634 - val_loss: 0.0561
# Epoch 34/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0632 - val_loss: 0.0562
# Epoch 35/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0629 - val_loss: 0.0555
# Epoch 36/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0626 - val_loss: 0.0553
# Epoch 37/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0624 - val_loss: 0.0550
# Epoch 38/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0621 - val_loss: 0.0547
# Epoch 39/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0620 - val_loss: 0.0543
# Epoch 40/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0618 - val_loss: 0.0547
# Epoch 41/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0617 - val_loss: 0.0542
# Epoch 42/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0615 - val_loss: 0.0541
# Epoch 43/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0613 - val_loss: 0.0536
# Epoch 44/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0611 - val_loss: 0.0535
# Epoch 45/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0610 - val_loss: 0.0531
# Epoch 46/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0608 - val_loss: 0.0531
# Epoch 47/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0607 - val_loss: 0.0533
# Epoch 48/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0606 - val_loss: 0.0531
# Epoch 49/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0604 - val_loss: 0.0526
# Epoch 50/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0603 - val_loss: 0.0528
# 313/313 [==============================] - 1s 2ms/step
# Latent dim => 32
# Epoch 1/50
# 94/94 [==============================] - 3s 11ms/step - loss: 0.1204 - val_loss: 0.1115
# Epoch 2/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1032 - val_loss: 0.0899
# Epoch 3/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0883 - val_loss: 0.0773
# Epoch 4/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0803 - val_loss: 0.0717
# Epoch 5/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0757 - val_loss: 0.0663
# Epoch 6/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0726 - val_loss: 0.0633
# Epoch 7/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0703 - val_loss: 0.0610
# Epoch 8/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0685 - val_loss: 0.0588
# Epoch 9/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0669 - val_loss: 0.0576
# Epoch 10/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0655 - val_loss: 0.0563
# Epoch 11/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0645 - val_loss: 0.0549
# Epoch 12/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0636 - val_loss: 0.0537
# Epoch 13/50
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0626 - val_loss: 0.0532
# Epoch 14/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0619 - val_loss: 0.0519
# Epoch 15/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0613 - val_loss: 0.0518
# Epoch 16/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0608 - val_loss: 0.0506
# Epoch 17/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0603 - val_loss: 0.0503
# Epoch 18/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0599 - val_loss: 0.0497
# Epoch 19/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0595 - val_loss: 0.0493
# Epoch 20/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0592 - val_loss: 0.0496
# Epoch 21/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0588 - val_loss: 0.0486
# Epoch 22/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0585 - val_loss: 0.0488
# Epoch 23/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0581 - val_loss: 0.0481
# Epoch 24/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0578 - val_loss: 0.0477
# Epoch 25/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0576 - val_loss: 0.0475
# Epoch 26/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0573 - val_loss: 0.0474
# Epoch 27/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0571 - val_loss: 0.0470
# Epoch 28/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0567 - val_loss: 0.0468
# Epoch 29/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0567 - val_loss: 0.0467
# Epoch 30/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0564 - val_loss: 0.0461
# Epoch 31/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0562 - val_loss: 0.0461
# Epoch 32/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0560 - val_loss: 0.0460
# Epoch 33/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0558 - val_loss: 0.0459
# Epoch 34/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0557 - val_loss: 0.0456
# Epoch 35/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0555 - val_loss: 0.0453
# Epoch 36/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0552 - val_loss: 0.0453
# Epoch 37/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0551 - val_loss: 0.0452
# Epoch 38/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0549 - val_loss: 0.0447
# Epoch 39/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0548 - val_loss: 0.0452
# Epoch 40/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0547 - val_loss: 0.0446
# Epoch 41/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0545 - val_loss: 0.0445
# Epoch 42/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0544 - val_loss: 0.0444
# Epoch 43/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0543 - val_loss: 0.0443
# Epoch 44/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0542 - val_loss: 0.0442
# Epoch 45/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0540 - val_loss: 0.0443
# Epoch 46/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0540 - val_loss: 0.0442
# Epoch 47/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0538 - val_loss: 0.0440
# Epoch 48/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0536 - val_loss: 0.0437
# Epoch 49/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0535 - val_loss: 0.0438
# Epoch 50/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0534 - val_loss: 0.0437
# 313/313 [==============================] - 1s 2ms/step
# Latent dim => 64
# Epoch 1/50
# 94/94 [==============================] - 3s 11ms/step - loss: 0.1198 - val_loss: 0.1073
# Epoch 2/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0989 - val_loss: 0.0869
# Epoch 3/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0870 - val_loss: 0.0781
# Epoch 4/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0805 - val_loss: 0.0720
# Epoch 5/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0762 - val_loss: 0.0670
# Epoch 6/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0729 - val_loss: 0.0632
# Epoch 7/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0704 - val_loss: 0.0618
# Epoch 8/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0684 - val_loss: 0.0590
# Epoch 9/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0669 - val_loss: 0.0575
# Epoch 10/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0657 - val_loss: 0.0565
# Epoch 11/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0645 - val_loss: 0.0546
# Epoch 12/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0637 - val_loss: 0.0538
# Epoch 13/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0628 - val_loss: 0.0529
# Epoch 14/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0621 - val_loss: 0.0520
# Epoch 15/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0613 - val_loss: 0.0513
# Epoch 16/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0608 - val_loss: 0.0510
# Epoch 17/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0602 - val_loss: 0.0503
# Epoch 18/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0597 - val_loss: 0.0496
# Epoch 19/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0593 - val_loss: 0.0499
# Epoch 20/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0589 - val_loss: 0.0488
# Epoch 21/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0586 - val_loss: 0.0483
# Epoch 22/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0582 - val_loss: 0.0479
# Epoch 23/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0579 - val_loss: 0.0477
# Epoch 24/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0575 - val_loss: 0.0474
# Epoch 25/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0573 - val_loss: 0.0470
# Epoch 26/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0570 - val_loss: 0.0470
# Epoch 27/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0567 - val_loss: 0.0465
# Epoch 28/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0564 - val_loss: 0.0460
# Epoch 29/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0562 - val_loss: 0.0463
# Epoch 30/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0559 - val_loss: 0.0458
# Epoch 31/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0556 - val_loss: 0.0458
# Epoch 32/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0554 - val_loss: 0.0451
# Epoch 33/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0552 - val_loss: 0.0453
# Epoch 34/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0549 - val_loss: 0.0453
# Epoch 35/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0548 - val_loss: 0.0449
# Epoch 36/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0546 - val_loss: 0.0446
# Epoch 37/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0544 - val_loss: 0.0449
# Epoch 38/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0542 - val_loss: 0.0446
# Epoch 39/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0540 - val_loss: 0.0443
# Epoch 40/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0539 - val_loss: 0.0442
# Epoch 41/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0538 - val_loss: 0.0446
# Epoch 42/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0536 - val_loss: 0.0439
# Epoch 43/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0535 - val_loss: 0.0442
# Epoch 44/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0533 - val_loss: 0.0440
# Epoch 45/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0532 - val_loss: 0.0440
# Epoch 46/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0530 - val_loss: 0.0441
# Epoch 47/50
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0530 - val_loss: 0.0434
# Epoch 48/50
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0528 - val_loss: 0.0436
# Epoch 49/50
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0527 - val_loss: 0.0432
# Epoch 50/50
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0526 - val_loss: 0.0430
# 313/313 [==============================] - 1s 2ms/step

# %%
def plot_image_comparision(index_of_image_to_compare):
    selected_image = X_test[index_of_image_to_compare]
    plt.figure(figsize=(20, 10))
    for i, latent_dim in enumerate(latent_dims):
        reconstructed_image = reconstructed_images[latent_dim][index_of_image_to_compare]

        # Display reconstructed image
        ax = plt.subplot(2, len(latent_dims), i + 1)
        plt.imshow(reconstructed_image.reshape(28, 28), cmap='gray')
        plt.title(f"Latent Dim: {latent_dim}\nPSNR: {psnr_values[i]:.2f}\nSSIM: {ssim_values[i]:.2f}")
        plt.axis('off')

    # Display the original image for comparison
    ax = plt.subplot(2, len(latent_dims), len(latent_dims) + 1)
    plt.imshow(selected_image.reshape(28, 28), cmap='gray')
    plt.title("Original Image")
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
# Select an image for comparison
plot_image_comparision(0)

# %%
# Select an image for comparison
plot_image_comparision(1)

# %%
# Select an image for comparison
plot_image_comparision(11)

# %%
# Plot the PSNR and SSIM graphs
fig, ax1 = plt.subplots(figsize=(8, 4))

# PSNR Plot
color = 'tab:red'
ax1.set_xlabel('Latent Dimension')
ax1.set_ylabel('PSNR (dB)', color=color)
ax1.plot(latent_dims, psnr_values, 'o-', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# SSIM Plot on the same x-axis
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('SSIM', color=color)
ax2.plot(latent_dims, ssim_values, 's-', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Layout and grid
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.grid(True)
plt.title('PSNR and SSIM Values for Different Latent Dimensions')

plt.show()

# %%
import os

# Create a directory to save the models if it doesn't already exist
model_save_dir = "/mnt/data/autoencoder_models"
os.makedirs(model_save_dir, exist_ok=True)

# Save each model in the autoencoders dictionary
for latent_dim, model in autoencoders.items():
    model_path = os.path.join(model_save_dir, f'autoencoder_D{latent_dim}.h5')
    model.save(model_path)
    print(f'Model with latent dim {latent_dim} saved to {model_path}')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model with latent dim 2 saved to /mnt/data/autoencoder_models/autoencoder_D2.h5
# Model with latent dim 8 saved to /mnt/data/autoencoder_models/autoencoder_D8.h5
# Model with latent dim 32 saved to /mnt/data/autoencoder_models/autoencoder_D32.h5
# Model with latent dim 64 saved to /mnt/data/autoencoder_models/autoencoder_D64.h5

# %%
# from tensorflow.keras.models import load_model

# def load_autoencoders(model_save_dir, latent_dims):
#     autoencoders_loaded = dict()
#     for latent_dim in latent_dims:
#         model_path = os.path.join(model_save_dir, f'autoencoder_D{latent_dim}.h5')
#         autoencoders_loaded[latent_dim] = load_model(model_path)
#         print(f'Model with latent dim {latent_dim} loaded from {model_path}')
#     return autoencoders_loaded

# # Assuming `latent_dims` is a list of the latent dimensions you used to save your models
# model_save_dir = "/mnt/data/autoencoder_models"
# autoencoders_loaded = load_autoencoders(model_save_dir, latent_dims)

# %%
def visualize_latent_space(encoder, X_test, y_test, num_classes=10):
    # Pass the test dataset through the encoder to obtain the latent representations
    latent_representations = encoder.predict(X_test)

    # Assuming the latent space is 2-dimensional
    z1 = latent_representations[:, 1]
    z2 = latent_representations[:, 2]

    plt.figure(figsize=(12, 10))
    cmap = plt.cm.get_cmap('hsv', num_classes)

    # Create a scatter plot, with color coding for each class
    for i in range(num_classes):
        indices = np.where(y_test == i)
        plt.scatter(z1[indices], z2[indices], label=i, s=2, cmap=cmap(i))

    # Add a color bar, set a title and labels, and display the plot
    cbar = plt.colorbar(ticks=range(num_classes))
    cbar.set_label('Digit Class')
    plt.xlabel('Encoder first dimension')
    plt.ylabel('Encoder second dimension')
    plt.title('Latent Space Visualization of MNIST Data')
    plt.legend()
    plt.grid(True)
    plt.show()


visualize_latent_space(encoders[64], X_test, Y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step
# <ipython-input-27-4f7b39a1d71f>:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('hsv', num_classes)
# <ipython-input-27-4f7b39a1d71f>:15: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(z1[indices], z2[indices], label=i, s=2, cmap=cmap(i))
